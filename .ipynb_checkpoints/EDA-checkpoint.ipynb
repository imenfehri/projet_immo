# %% [markdown]
# # EDA (descriptions des variables, analyses univariées, bivariées)

# %% [raw]
# 1/présentation des données
# on a une base de données qui contient les prix médians des logements pour les districts de Californie issus du recensement
# de 1990, on 16512 données:
#
# 1/longitude.
# 2/latitude.
# 3/housingMedianAge: Âge médian d une maison dans un pâté de maisons; un chiffre plus bas correspond à un bâtiment plus récent.
# 4/totalRooms: Nombre total de chambres dans un bloc.
# 5/totalBedrooms: Nombre total de chambres dans un bloc.
# 6/population: Nombre total de personnes résidant dans un bloc.
# 7/households: Nombre total de ménages, c'est-à-dire un groupe de personnes résidant dans une unité d'habitation, pour un bloc.
# 8/medianIncome: Revenu médian des ménages dans un bloc de maisons (mesuré en dizaines de milliers de dollars US)
# 9/medianHouseValue: Valeur médiane des maisons pour les ménages d'un bloc (mesurée en dollars US) 10/oceanProximity: Situation de la maison par rapport à la mer

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as plt
from matplotlib import pyplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://simplonline-v3-prod.s3.eu-west-3.amazonaws.com/media/file/csv/4054a881-9509-4cc0-9501-1174d5bbf6fc.csv')
data
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# 0               473.0      1397.0       417.0         1.4817
# 1               349.0       862.0       340.0         6.9133
# 2               214.0       931.0       214.0         1.5536
# 3               229.0       597.0       227.0         1.5284
# 4               373.0      1130.0       372.0         4.0815
# ...               ...         ...         ...            ...
# 16507           278.0       745.0       250.0         3.0625
# 16508           504.0      1131.0       458.0         2.6133
# 16509           461.0      1206.0       429.0         4.4958
# 16510           840.0      2546.0       773.0         2.5750
# 16511           462.0      1259.0       420.0         2.2478
#
#        median_house_value ocean_proximity
# 0                 72000.0          INLAND
# 1                274100.0       <1H OCEAN
# 2                 58300.0          INLAND
# 3                200000.0       <1H OCEAN
# 4                117900.0          INLAND
# ...                   ...             ...
# 16507             93800.0          INLAND
# 16508            103100.0        NEAR BAY
# 16509            192600.0          INLAND
# 16510            153500.0       <1H OCEAN
# 16511             81100.0      NEAR OCEAN
#
# [16512 rows x 11 columns]

# %%
data2=data.copy()

# %%
data2.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data2.shape
# Out:
# (16512, 10)

# %%
data2.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
data.dtypes.value_counts()
# Out:
# float64    9
# object     1
# int64      1
# dtype: int64

# %%
data.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # nettoyage de la basse de données

# %% [markdown]
# # 1 les valeurs manquantes

# %%
# Trying to sum all the missing values with isnull().sum()
data2.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        176
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
sns.heatmap(data.isna())
# Out:
# <AxesSubplot:>

# %%
#on peux regarder qu'onà 176 valeurs manquantes c'est pas beaucoup parrapport la quantité des donnés qu'on a

# %%
# Remplacer en utilisant la médiane
median = data2['total_bedrooms'].median()
data2['total_bedrooms'].fillna(median, inplace=True)

# %% [markdown]
# # 2 les valeurs dupliqués

# %%
#trouver les valeurs manquantes
data2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 3 la valeurs abbérantes(outliers)

# %%
columns = list(data.columns)
data2.plot(kind='box', subplots=True, layout=(4, 4), figsize = (12, 12));

# %%
#Plot the Distribution plots for the features
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(data2['total_bedrooms'])
plt.subplot(1,2,2)
sns.distplot(data2['population'])
plt.show()

# %%
#Finding the Boundary Values
print("Highest allowed",data2['population'].mean() + 3*data2['population'].std())
print("Lowest allowed",data2['population'].mean() - 3*data2['population'].std())
# Out:
# Highest allowed 4909.47316245515
# Lowest allowed -2039.438642106312

# %%
# Finding the Outliers
data2[(data2['population'] > 4909.47) | (data2['population'] < -2039.43)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20       -117.85     34.11                25.0       9255.0          1659.0
# 29       -121.94     38.27                35.0      10869.0          2226.0
# 57       -118.42     33.75                22.0      17591.0          2604.0
# 137      -122.07     37.57                 8.0       8647.0          1407.0
# 154      -122.47     37.65                27.0       8103.0          1655.0
# ...          ...       ...                 ...          ...             ...
# 16101    -118.33     33.91                 8.0      10731.0          3335.0
# 16129    -122.10     37.63                18.0       9963.0          2031.0
# 16321    -118.40     34.28                16.0       6573.0          1480.0
# 16337    -117.22     33.90                 8.0       8302.0          1461.0
# 16358    -118.05     34.08                25.0       4909.0          1422.0
#
#        population  households  median_income  median_house_value  \
# 20         4944.0      1627.0         4.5708            223000.0
# 29         9879.0      2152.0         2.5681             81300.0
# 57         6897.0      2492.0         8.2831            500001.0
# 137        5019.0      1379.0         6.5615            318300.0
# 154        5023.0      1605.0         4.6452            236200.0
# ...           ...         ...            ...                 ...
# 16101      7211.0      3028.0         2.4550            192700.0
# 16129      5613.0      1946.0         3.8171            187200.0
# 16321      6161.0      1473.0         3.3304            154900.0
# 16337      5155.0      1370.0         4.0467            121500.0
# 16358      4983.0      1293.0         2.7254            143500.0
#
#       ocean_proximity
# 20             INLAND
# 29             INLAND
# 57         NEAR OCEAN
# 137          NEAR BAY
# 154        NEAR OCEAN
# ...               ...
# 16101       <1H OCEAN
# 16129        NEAR BAY
# 16321       <1H OCEAN
# 16337          INLAND
# 16358       <1H OCEAN
#
# [260 rows x 10 columns]

# %%
#Trimming of Outliers
new_df = data2[(data2['population'] > 4909.47) | (data2['population'] < -2039.43)]
new_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20       -117.85     34.11                25.0       9255.0          1659.0
# 29       -121.94     38.27                35.0      10869.0          2226.0
# 57       -118.42     33.75                22.0      17591.0          2604.0
# 137      -122.07     37.57                 8.0       8647.0          1407.0
# 154      -122.47     37.65                27.0       8103.0          1655.0
# ...          ...       ...                 ...          ...             ...
# 16101    -118.33     33.91                 8.0      10731.0          3335.0
# 16129    -122.10     37.63                18.0       9963.0          2031.0
# 16321    -118.40     34.28                16.0       6573.0          1480.0
# 16337    -117.22     33.90                 8.0       8302.0          1461.0
# 16358    -118.05     34.08                25.0       4909.0          1422.0
#
#        population  households  median_income  median_house_value  \
# 20         4944.0      1627.0         4.5708            223000.0
# 29         9879.0      2152.0         2.5681             81300.0
# 57         6897.0      2492.0         8.2831            500001.0
# 137        5019.0      1379.0         6.5615            318300.0
# 154        5023.0      1605.0         4.6452            236200.0
# ...           ...         ...            ...                 ...
# 16101      7211.0      3028.0         2.4550            192700.0
# 16129      5613.0      1946.0         3.8171            187200.0
# 16321      6161.0      1473.0         3.3304            154900.0
# 16337      5155.0      1370.0         4.0467            121500.0
# 16358      4983.0      1293.0         2.7254            143500.0
#
#       ocean_proximity
# 20             INLAND
# 29             INLAND
# 57         NEAR OCEAN
# 137          NEAR BAY
# 154        NEAR OCEAN
# ...               ...
# 16101       <1H OCEAN
# 16129        NEAR BAY
# 16321       <1H OCEAN
# 16337          INLAND
# 16358       <1H OCEAN
#
# [260 rows x 10 columns]

# %%
#Capping on Outliers
upper_limit = data2['population'].mean() + 3*data2['population'].std()
lower_limit = data2['population'].mean() - 3*data2['population'].std()

# %%
#Now, apply the Capping
data2['population'] = np.where(
    data2['population']>upper_limit,
    upper_limit,
    np.where(
        data2['population']<lower_limit,
        lower_limit,
        data2['population']
    )
)

# %%
data2['population'].describe()
# Out:
# count    16512.000000
# mean      1399.740372
# std        935.268627
# min          3.000000
# 25%        788.000000
# 50%       1168.000000
# 75%       1738.000000
# max       4909.473162
# Name: population, dtype: float64

# %%
data['population'].describe()
# Out:
# count    16512.000000
# mean      1435.017260
# std       1158.151967
# min          3.000000
# 25%        788.000000
# 50%       1168.000000
# 75%       1738.000000
# max      35682.000000
# Name: population, dtype: float64

# %%
#aprés le traitement des outliers on peux remarqué que il y'a une petite différence et que ces valeurs abérantes n'auront aucun 
#effet sur nos modéles

# %% [markdown]
# # diviser notre data set entre le Xtrain et Xtest

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# We need to split our dataframe, because we want one train_df (70% of data) and one test_df (30% of data)
train_df, test_df = train_test_split(data2, train_size=0.7, test_size=0.3)

# %% [markdown]
# # pre-processing

# %% [markdown]
# # 1 encodage

# %%
#on va utliser la methode OneHotEncoder
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
## load dataset
#train_df.columns

# %% [raw]
# # le = preprocessing.LabelEncoder()
# train_df["ocean_proximity"] =le.fit_transform(train_df["ocean_proximity"])

# %%
le = preprocessing.LabelEncoder()
enc = preprocessing.OneHotEncoder()
train_df["ocean_proximity"] =le.fit_transform(train_df["ocean_proximity"])
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8580     -117.28     32.74                33.0       4168.0          1112.0
# 10659    -122.09     37.70                33.0       4413.0          1107.0
# 5778     -117.94     33.94                25.0       3250.0           546.0
# 6370     -122.15     37.43                47.0       2600.0           490.0
# 11528    -122.08     37.70                32.0       2718.0           447.0
# ...          ...       ...                 ...          ...             ...
# 1849     -119.83     36.79                24.0       3505.0           819.0
# 11202    -118.11     34.10                20.0       3090.0           802.0
# 2334     -122.84     38.98                21.0        939.0           176.0
# 6114     -121.03     37.69                 5.0       4034.0           771.0
# 10755    -122.43     37.79                24.0       2459.0          1001.0
#
#        population  households  median_income  median_house_value  \
# 8580       1785.0       984.0         2.7515            247700.0
# 10659      2239.0      1051.0         2.9861            208200.0
# 5778       1452.0       501.0         5.1084            303800.0
# 6370       1149.0       465.0         5.0203            476300.0
# 11528      1156.0       410.0         5.2497            259300.0
# ...           ...         ...            ...                 ...
# 1849       2098.0       774.0         1.9575             67000.0
# 11202      2109.0       738.0         3.3801            192500.0
# 2334        556.0       178.0         1.7196             75000.0
# 6114       1967.0       742.0         3.8065            146000.0
# 10755      1362.0       957.0         2.6782            450000.0
#
#        ocean_proximity
# 8580                 4
# 10659                3
# 5778                 0
# 6370                 3
# 11528                3
# ...                ...
# 1849                 1
# 11202                0
# 2334                 1
# 6114                 1
# 10755                3
#
# [11558 rows x 10 columns]

# %% [markdown]
# # 1 standardiser la partie train_df

# %%
from sklearn.preprocessing import StandardScaler
# We know that there is a problem with the scale of our features. We will use sklearn to do that.

# First, we define StandardScaler()
scaler = StandardScaler()

# Then, we scale our data, selecting only the column that we want to scale.
scaled_df = scaler.fit_transform(train_df.iloc[:, 2:9].to_numpy())

# Finaly, we create a dataframe to store these values.
scaled_df = pd.DataFrame(scaled_df, columns=['housing_median_age','total_rooms',
                                             'total_bedrooms','population',
                                             'households','median_income','median_house_value'])
 
print("Scaled Dataset Using StandardScaler")
scaled_df
# Out:
# Scaled Dataset Using StandardScaler
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                0.354520     0.652929        1.308451    0.409770
# 1                0.354520     0.759577        1.296988    0.891623
# 2               -0.279652     0.253326        0.010858    0.056340
# 3                1.464321    -0.029618       -0.117525   -0.265249
# 4                0.275249     0.021747       -0.216106   -0.257819
# ...                   ...          ...             ...         ...
# 11553           -0.358923     0.364327        0.636729    0.741972
# 11554           -0.676009     0.183678        0.597755    0.753647
# 11555           -0.596738    -0.752649       -0.837391   -0.894629
# 11556           -1.865082     0.594599        0.526686    0.602936
# 11557           -0.358923    -0.090995        1.053976   -0.039181
#
#        households  median_income  median_house_value
# 0        1.211987      -0.594512            0.337250
# 1        1.380979      -0.472402           -0.002046
# 2       -0.006270       0.632261            0.819136
# 3       -0.097071       0.586404            2.300871
# 4       -0.235796       0.705808            0.436891
# ...           ...            ...                 ...
# 11553    0.682310      -1.007791           -1.214920
# 11554    0.591509      -0.267324           -0.136905
# 11555   -0.820963      -1.131619           -1.146202
# 11556    0.601598      -0.045382           -0.536329
# 11557    1.143886      -0.632665            2.074960
#
# [11558 rows x 7 columns]

# %%
# We need to add the new scaled data to the ocean_proximity
scaled_df['ocean_proximity'] = train_df['ocean_proximity']

# Then we will add the longitude and latitude

scaled_df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                0.354520     0.652929        1.308451    0.409770
# 1                0.354520     0.759577        1.296988    0.891623
# 2               -0.279652     0.253326        0.010858    0.056340
# 3                1.464321    -0.029618       -0.117525   -0.265249
# 4                0.275249     0.021747       -0.216106   -0.257819
# ...                   ...          ...             ...         ...
# 11553           -0.358923     0.364327        0.636729    0.741972
# 11554           -0.676009     0.183678        0.597755    0.753647
# 11555           -0.596738    -0.752649       -0.837391   -0.894629
# 11556           -1.865082     0.594599        0.526686    0.602936
# 11557           -0.358923    -0.090995        1.053976   -0.039181
#
#        households  median_income  median_house_value  ocean_proximity
# 0        1.211987      -0.594512            0.337250              1.0
# 1        1.380979      -0.472402           -0.002046              0.0
# 2       -0.006270       0.632261            0.819136              1.0
# 3       -0.097071       0.586404            2.300871              0.0
# 4       -0.235796       0.705808            0.436891              NaN
# ...           ...            ...                 ...              ...
# 11553    0.682310      -1.007791           -1.214920              0.0
# 11554    0.591509      -0.267324           -0.136905              1.0
# 11555   -0.820963      -1.131619           -1.146202              1.0
# 11556    0.601598      -0.045382           -0.536329              1.0
# 11557    1.143886      -0.632665            2.074960              4.0
#
# [11558 rows x 8 columns]

# %%
scaled_df.to_csv("C:/Users/Imen/Desktop/projet immobilier/scaled_df.csv", index=False)
train_df.to_csv("C:/Users/Imen/Desktop/projet immobilier/train_df.csv", index=False)
